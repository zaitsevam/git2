# %% [markdown]
# <a href="https://colab.research.google.com/github/zaitsevam/git2/blob/main/Recycling_rate_waste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
# %cd drive/MyDrive/TechLabs/02_Data\ Manipulation/Part\ C\ -\ Pandas
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/TechLabs/02_Data Manipulation/Part C - Pandas'
# /content/drive/MyDrive/TechLabs/02_Data Manipulation/Part C - Pandas

# %%
# This is the convention used to import Pandas.
import pandas as pd
import numpy as np

# %%
# These commands load the data from googlecolab
bycountry = pd.read_csv("data/sdg_11_60_page_linear.csv")

# %%
bycountry
# Out:
#                  DATAFLOW        LAST UPDATE freq unit geo  TIME_PERIOD  \
# 0    ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AL         2020
# 1    ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AL         2021
# 2    ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2000
# 3    ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2001
# 4    ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2002
# ..                    ...                ...  ...  ...  ..          ...
# 712  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  UK         2016
# 713  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  UK         2017
# 714  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  UK         2018
# 715  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  XK         2020
# 716  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  XK         2021
#
#      OBS_VALUE OBS_FLAG
# 0         18.1      NaN
# 1         18.7      NaN
# 2         63.4      NaN
# ...

# %%
#delete irrelevant columns for data analysis
bycountry.drop("DATAFLOW", inplace=True, axis=1)
bycountry.drop("LAST UPDATE", inplace=True, axis=1)
bycountry.drop("freq", inplace=True, axis=1)
bycountry.drop("unit", inplace=True, axis=1)
bycountry.head()
# Out:
#   geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0  AL         2020       18.1      NaN
# 1  AL         2021       18.7      NaN
# 2  AT         2000       63.4      NaN
# 3  AT         2001       64.3        e
# 4  AT         2002       62.5        e

# %%
#see all unique values of series object ["OBS_FLAG"]
#"OBS_FLAG" simply describes the nature of the data
## "nan": "no_additional_information", "e": "estimated" "b":"break_in_time_series", "p": "provisional", "be":"break_in_time_series,estimated", "ep": "estimated,provisional", "es":"Eurostat_estimated"
bycountry["OBS_FLAG"].unique()
# Out:
# array([nan, 'e', 'b', 'p', 'be', 's', 'ep', 'es'], dtype=object)

# %%
#delete one additional column for data analysis as no impact on data
bycountry.drop("OBS_FLAG", inplace=True, axis=1)
bycountry.head()
# Out:
#   geo  TIME_PERIOD  OBS_VALUE
# 0  AL         2020       18.1
# 1  AL         2021       18.7
# 2  AT         2000       63.4
# 3  AT         2001       64.3
# 4  AT         2002       62.5

# %%
bycountry.rename(columns={"geo": "region_id", "TIME_PERIOD":"year", "OBS_VALUE":"recycling_rate_municipal_waste_percent"}, inplace=True)
bycountry.head()
# Out:
#   region_id  year  recycling_rate_municipal_waste_percent
# 0        AL  2020                                    18.1
# 1        AL  2021                                    18.7
# 2        AT  2000                                    63.4
# 3        AT  2001                                    64.3
# 4        AT  2002                                    62.5

# %%
#add column with the name of the country
bycountry["country_name"]=bycountry.region_id.replace({"EU27_2020":"European Union - 27 countries (from 2020)",
                                                        "EUR28":"European Union - 28 countries (2013-2020)", 
                                                        "BE": "Belgium", 
                                                        "BG": "Bulgaria",
                                                        "CZ": "Czechia",
                                                        "DK": "Denmark", 
                                                        "DE": "Germany (until 1990 former territory of the FRG)",
                                                        "EE": "Estonia",
                                                        "IE": "Ireland",
                                                        "EL": "Greece",
                                                        "ES": "Spain",
                                                        "FR": "France",
                                                        "HR": "Croatia",
                                                        "IT": "Italy",
                                                        "CY": "Cyprus",
                                                        "LV": "Latvia",
                                                        "LT": "Lithuania",
                                                        "LU": "Luxembourg",
                                                        "HU": "Hungary",
                                                        "MT": "Malta",
                                                        "NL": "Netherlands",
                                                        "AT": "Austria",
                                                        "PL": "Poland",
                                                        "PT": "Portugal",
                                                        "RO": "Romania",
                                                        "ST": "Slovenia",
                                                        "SK": "Slovakia",
                                                        "FI": "Finland",
                                                        "SE": "Sweden",
                                                        "IS": "Iceland",
                                                        "NO": "Norway",
                                                        "CH": "Switzerland",
                                                        "UK": "United Kingdom",
                                                        "BA": "Bosnia and Herzegovina",
                                                        "ME": "Montenegro",
                                                        "MK": "North Macedonia",
                                                        "AL":  "Albania",
                                                        "RS": "Serbia",
                                                        "TR": "Türkiye",
                                                        "XK": "Kosovo (under United Nations Security Council Resolution 1244/99)"})
bycountry
# Out:
#     region_id  year  recycling_rate_municipal_waste_percent  \
# 0          AL  2020                                    18.1
# 1          AL  2021                                    18.7
# 2          AT  2000                                    63.4
# 3          AT  2001                                    64.3
# 4          AT  2002                                    62.5
# ..        ...   ...                                     ...
# 712        UK  2016                                    44.0
# 713        UK  2017                                    43.8
# 714        UK  2018                                    44.1
# 715        XK  2020                                     0.0
# 716        XK  2021                                     0.0
#
#                                           country_name
# 0                                              Albania
# 1                                              Albania
# 2                                              Austria
# ...

# %%
#visualle re-check whether all ID are correctly renamed (one mistake ound for Finnland (FT instead of correct FI); corrected directly)
bycountry["country_name"].unique()
# Out:
# array(['Albania', 'Austria', 'Bosnia and Herzegovina', 'Belgium',
#        'Bulgaria', 'Switzerland', 'Cyprus', 'Czechia',
#        'Germany (until 1990 former territory of the FRG)', 'Denmark',
#        'Estonia', 'Greece', 'Spain',
#        'European Union - 27 countries (from 2020)', 'Finland', 'France',
#        'Croatia', 'Hungary', 'Ireland', 'Iceland', 'Italy', 'Lithuania',
#        'Luxembourg', 'Latvia', 'Montenegro', 'North Macedonia', 'Malta',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia',
#        'Sweden', 'SI', 'Slovakia', 'Türkiye', 'United Kingdom',
#        'Kosovo (under United Nations Security Council Resolution 1244/99)'],
#       dtype=object)

# %%
#Count the number of unique values and compare to the "country_name" 
bycountry["region_id"].nunique()
# Out:
# 39

# %%
#Count the number of unique values
bycountry["country_name"].nunique()
# Out:
# 39

# %%
#whether or not the values classified as NA values
bycountry.isna()
# Out:
#      region_id   year  recycling_rate_municipal_waste_percent  country_name
# 0        False  False                                   False         False
# 1        False  False                                   False         False
# 2        False  False                                   False         False
# 3        False  False                                   False         False
# 4        False  False                                   False         False
# ..         ...    ...                                     ...           ...
# 712      False  False                                   False         False
# 713      False  False                                   False         False
# 714      False  False                                   False         False
# 715      False  False                                   False         False
# 716      False  False                                   False         False
#
# [717 rows x 4 columns]

# %%
#check for MISSING values
print(bycountry.region_id.value_counts().sum())
print(bycountry.shape)
# Out:
# 717
# (717, 4)

# %%
#check missing values directly through each columns
pd.isnull(bycountry.year).sum()
# Out:
# 0

# %%
#check missing values directly through each columns
pd.isnull(bycountry.recycling_rate_municipal_waste_percent).sum()
# Out:
# 0

# %%
#check missing values directly through each columns
pd.isnull(bycountry.country_name).sum()
# Out:
# 0

# %%
#place country_name column next to reqion_id
column_to_move = bycountry.pop("country_name")
bycountry.insert(0, "country_name", column_to_move)
bycountry.head()
# Out:
#   country_name region_id  year  recycling_rate_municipal_waste_percent
# 0      Albania        AL  2020                                    18.1
# 1      Albania        AL  2021                                    18.7
# 2      Austria        AT  2000                                    63.4
# 3      Austria        AT  2001                                    64.3
# 4      Austria        AT  2002                                    62.5
