# %% [markdown]
# <a href="https://colab.research.google.com/github/zaitsevam/git2/blob/main/Joined_data_with_visualisation_add_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
# %cd drive/MyDrive/TechLabs/02_Data\ Manipulation/Part\ C\ -\ Pandas
# Out:
# /content/drive/MyDrive/TechLabs/02_Data Manipulation/Part C - Pandas

# %%
# This is the convention used to import Pandas.
import pandas as pd
import numpy as np

# %%
waste = pd.read_csv("data/cei_pc031_page_linear.csv")
recycle = pd.read_csv("data/sdg_11_60_page_linear.csv")
population = pd.read_csv("data/demo_pjan__custom_5181490_page_linear.csv")

# %%
#Dataset 1: Generation of municipal waste per capita in kg (Europe)
waste.head()
# Out:
#                DATAFLOW        LAST UPDATE freq wst_oper    unit geo  \
# 0  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 1  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 2  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 3  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
# 4  ESTAT:CEI_PC031(1.0)  17/02/23 23:00:00    A      GEN  KG_HAB  AL
#
#    TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0         2013        325        s
# 1         2014        425        s
# 2         2015        491        s
# 3         2016        452        e
# 4         2017        436        e

# %%
#Dataset 2: Recycling rate of municipal waste in % (Europe)
recycle.head()
# Out:
#                DATAFLOW        LAST UPDATE freq unit geo  TIME_PERIOD  \
# 0  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AL         2020
# 1  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AL         2021
# 2  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2000
# 3  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2001
# 4  ESTAT:SDG_11_60(1.0)  13/01/23 23:00:00    A   PC  AT         2002
#
#    OBS_VALUE OBS_FLAG
# 0       18.1      NaN
# 1       18.7      NaN
# 2       63.4      NaN
# 3       64.3        e
# 4       62.5        e

# %%
#Dataset 3: Population on 1 January by age and sex (Europe)
population.head()
# Out:
#                DATAFLOW        LAST UPDATE freq unit    age sex geo  \
# 0  ESTAT:DEMO_PJAN(1.0)  22/02/23 11:00:00    A   NR  TOTAL   T  AD
# 1  ESTAT:DEMO_PJAN(1.0)  22/02/23 11:00:00    A   NR  TOTAL   T  AD
# 2  ESTAT:DEMO_PJAN(1.0)  22/02/23 11:00:00    A   NR  TOTAL   T  AD
# 3  ESTAT:DEMO_PJAN(1.0)  22/02/23 11:00:00    A   NR  TOTAL   T  AD
# 4  ESTAT:DEMO_PJAN(1.0)  22/02/23 11:00:00    A   NR  TOTAL   T  AD
#
#    TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0         2000    65971.0      NaN
# 1         2001    65844.0      NaN
# 2         2002    66334.0      NaN
# 3         2003    67159.0      NaN
# 4         2004    72320.0      NaN

# %%
#delete irrelevant columns for the data analysis from both datasets
waste.drop("DATAFLOW", inplace=True, axis=1)
waste.drop("LAST UPDATE", inplace=True, axis=1)
waste.drop("freq", inplace=True, axis=1)
waste.drop("wst_oper", inplace=True, axis=1)
waste.drop("unit", inplace=True, axis=1)
waste.drop("OBS_FLAG", inplace=True, axis=1)
recycle.drop("DATAFLOW", inplace=True, axis=1)
recycle.drop("LAST UPDATE", inplace=True, axis=1)
recycle.drop("freq", inplace=True, axis=1)
recycle.drop("unit", inplace=True, axis=1)
recycle.drop("OBS_FLAG", inplace=True, axis=1)
population.drop("DATAFLOW", inplace=True, axis=1)
population.drop("LAST UPDATE", inplace=True, axis=1)
population.drop("freq", inplace=True, axis=1)
population.drop("unit", inplace=True, axis=1)
population.drop("OBS_FLAG", inplace=True, axis=1)
population.drop("sex", inplace=True, axis=1) #because all sex
population.drop("age", inplace=True, axis=1) #because all ages

# %%
#rename columns in both datasets
waste.rename(columns={"geo": "region_id", "TIME_PERIOD":"year", "OBS_VALUE":"municipal_waste_per_capita_kg"}, inplace=True)
recycle.rename(columns={"geo": "region_id", "TIME_PERIOD":"year", "OBS_VALUE":"recycling_rate_municipal_waste_percent"}, inplace=True)
population.rename(columns={"geo": "region_id", "TIME_PERIOD":"year", "OBS_VALUE":"population"}, inplace=True)

# %%
#INNER JOIN ("recycle" + "waste") --> set of records that have a mutual value in the specified joining column(s)
join_1=waste.merge(recycle, on =["region_id", "year"])
join_1.head()
# Out:
#   region_id  year  municipal_waste_per_capita_kg  \
# 0        AL  2020                            369
# 1        AL  2021                            311
# 2        AT  2000                            580
# 3        AT  2001                            576
# 4        AT  2002                            608
#
#    recycling_rate_municipal_waste_percent
# 0                                    18.1
# 1                                    18.7
# 2                                    63.4
# 3                                    64.3
# 4                                    62.5

# %%
#INNER JOIN ("recycle" + "waste"+"population")
joined=join_1.merge(population, on =["region_id", "year"])
joined.head()
# Out:
#   region_id  year  municipal_waste_per_capita_kg  \
# 0        AL  2020                            369
# 1        AL  2021                            311
# 2        AT  2000                            580
# 3        AT  2001                            576
# 4        AT  2002                            608
#
#    recycling_rate_municipal_waste_percent  population
# 0                                    18.1   2845955.0
# 1                                    18.7   2829741.0
# 2                                    63.4   8002186.0
# 3                                    64.3   8020946.0
# 4                                    62.5   8063640.0

# %%
#unique values of series object ["region_id"]
joined["region_id"].unique()
# Out:
# array(['AL', 'AT', 'BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE',
#        'EL', 'ES', 'EU27_2020', 'FI', 'FR', 'HR', 'HU', 'IE', 'IS', 'IT',
#        'LT', 'LU', 'LV', 'ME', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO',
#        'RS', 'SE', 'SI', 'SK', 'TR', 'UK', 'XK'], dtype=object)

# %%
#add a new column and assign the country name to it
joined["country_name"]=joined.region_id.replace({"EU27_2020": "European Union - 27 countries (from 2020)",
"BE": "Belgium",
"BG": "Bulgaria",
"CZ": "Czechia",
"DK": "Denmark",
"DE": "Germany",
"EE": "Estonia",
"IE": "Ireland",
"EL": "Greece",
"ES": "Spain",
"FR": "France",
"HR": "Croatia",
"CY": "Cyprus",
"IT": "Italy",
"IS": "Iceland",
"LV": "Latvia",
"LT": "Lithuania",
"LU": "Luxembourg",
"HU": "Hungary",
"MT": "Malta",
"NL": "Netherlands",
"AT": "Austria",
"PL": "Poland",
"PT": "Portugal",
"RO": "Romania",
"SI": "Slovenia",
"SK": "Slovakia",
"FI": "Finland",
"SE": "Sweden",
"IS": "Iceland",
"LI": "Lichtenstein",
"NO": "Norway",
"CH": "Switzerland",
"UK": "United Kingdom",
"BA": "Bosnia and Herzegovina",
"ME": "Montenegro",
"MK": "North Macedonia",
"AL": "Albania",
"RS": "Serbia",
"TR": "Türkiye",
"XK": "Kosovo"
})

# %%
#recheck the number of the assigned variables
joined["country_name"].nunique()
# Out:
# 39

# %%
# ok
joined["region_id"].nunique()
# Out:
# 39

# %%
#move the column ["country_name"] before ["region_id"]
column_to_move = joined.pop("country_name")
joined.insert(0, "country_name", column_to_move)
joined.head()
# Out:
#   country_name region_id  year  municipal_waste_per_capita_kg  \
# 0      Albania        AL  2020                            369
# 1      Albania        AL  2021                            311
# 2      Austria        AT  2000                            580
# 3      Austria        AT  2001                            576
# 4      Austria        AT  2002                            608
#
#    recycling_rate_municipal_waste_percent  population
# 0                                    18.1   2845955.0
# 1                                    18.7   2829741.0
# 2                                    63.4   8002186.0
# 3                                    64.3   8020946.0
# 4                                    62.5   8063640.0

# %%
#replace zero value with NAN
joined.replace(0, np.nan, inplace=True)
joined.head(30)
# Out:
#               country_name region_id  year  municipal_waste_per_capita_kg  \
# 0                  Albania        AL  2020                            369
# 1                  Albania        AL  2021                            311
# 2                  Austria        AT  2000                            580
# 3                  Austria        AT  2001                            576
# 4                  Austria        AT  2002                            608
# 5                  Austria        AT  2003                            607
# 6                  Austria        AT  2004                            574
# 7                  Austria        AT  2005                            575
# 8                  Austria        AT  2006                            597
# 9                  Austria        AT  2007                            597
# 10                 Austria        AT  2008                            600
# 11                 Austria        AT  2009                            590
# 12                 Austria        AT  2010                            562
# 13                 Austria        AT  2011                            573
# 14                 Austria        AT  2012                            579
# 15                 Austria        AT  2013                            578
# 16                 Austria        AT  2014                            565
# 17                 Austria        AT  2015                            560
# 18                 Austria        AT  2016                            564
# 19                 Austria        AT  2017                            570
# 20                 Austria        AT  2018                            579
# 21                 Austria        AT  2019                            588
# 22                 Austria        AT  2020                            834
# 23  Bosnia and Herzegovina        BA  2008                            356
# 24  Bosnia and Herzegovina        BA  2009                            354
# 25  Bosnia and Herzegovina        BA  2010                            332
# 26  Bosnia and Herzegovina        BA  2011                            340
# 27  Bosnia and Herzegovina        BA  2012                            340
# 28                 Belgium        BE  2000                            471
# 29                 Belgium        BE  2001                            467
#
#     recycling_rate_municipal_waste_percent  population
# 0                                     18.1   2845955.0
# 1                                     18.7   2829741.0
# 2                                     63.4   8002186.0
# 3                                     64.3   8020946.0
# 4                                     62.5   8063640.0
# 5                                     64.2   8100273.0
# 6                                     57.4   8142573.0
# 7                                     58.3   8201359.0
# 8                                     59.2   8254298.0
# 9                                     60.2   8282984.0
# 10                                    63.2   8307989.0
# 11                                    61.9   8335003.0
# 12                                    59.4   8351643.0
# 13                                    56.7   8375164.0
# 14                                    57.7   8408121.0
# 15                                    57.7   8451860.0
# 16                                    56.3   8507786.0
# 17                                    56.9   8584926.0
# 18                                    57.6   8700471.0
# 19                                    57.8   8772865.0
# 20                                    57.7   8822267.0
# 21                                    58.2   8858775.0
# 22                                    62.3   8901064.0
# 23                                     NaN   3843846.0
# 24                                     NaN   3843998.0
# 25                                     NaN   3844046.0
# 26                                     NaN   3843183.0
# 27                                     NaN   3839265.0
# 28                                    49.7  10239085.0
# 29                                    50.4  10263414.0

# %%
#delete missing values
joined.dropna(inplace=True)
joined.head(40)
# Out:
#    country_name region_id  year  municipal_waste_per_capita_kg  \
# 0       Albania        AL  2020                            369
# 1       Albania        AL  2021                            311
# 2       Austria        AT  2000                            580
# 3       Austria        AT  2001                            576
# 4       Austria        AT  2002                            608
# 5       Austria        AT  2003                            607
# 6       Austria        AT  2004                            574
# 7       Austria        AT  2005                            575
# 8       Austria        AT  2006                            597
# 9       Austria        AT  2007                            597
# 10      Austria        AT  2008                            600
# 11      Austria        AT  2009                            590
# 12      Austria        AT  2010                            562
# 13      Austria        AT  2011                            573
# 14      Austria        AT  2012                            579
# 15      Austria        AT  2013                            578
# 16      Austria        AT  2014                            565
# 17      Austria        AT  2015                            560
# 18      Austria        AT  2016                            564
# 19      Austria        AT  2017                            570
# 20      Austria        AT  2018                            579
# 21      Austria        AT  2019                            588
# 22      Austria        AT  2020                            834
# 28      Belgium        BE  2000                            471
# 29      Belgium        BE  2001                            467
# 30      Belgium        BE  2002                            482
# 31      Belgium        BE  2003                            465
# 32      Belgium        BE  2004                            485
# 33      Belgium        BE  2005                            482
# 34      Belgium        BE  2006                            485
# 35      Belgium        BE  2007                            493
# 36      Belgium        BE  2008                            480
# 37      Belgium        BE  2009                            467
# 38      Belgium        BE  2010                            456
# 39      Belgium        BE  2011                            455
# 40      Belgium        BE  2012                            445
# 41      Belgium        BE  2013                            436
# 42      Belgium        BE  2014                            425
# 43      Belgium        BE  2015                            412
# 44      Belgium        BE  2016                            419
#
#     recycling_rate_municipal_waste_percent  population
# 0                                     18.1   2845955.0
# 1                                     18.7   2829741.0
# 2                                     63.4   8002186.0
# 3                                     64.3   8020946.0
# 4                                     62.5   8063640.0
# 5                                     64.2   8100273.0
# 6                                     57.4   8142573.0
# 7                                     58.3   8201359.0
# 8                                     59.2   8254298.0
# 9                                     60.2   8282984.0
# 10                                    63.2   8307989.0
# 11                                    61.9   8335003.0
# 12                                    59.4   8351643.0
# 13                                    56.7   8375164.0
# 14                                    57.7   8408121.0
# 15                                    57.7   8451860.0
# 16                                    56.3   8507786.0
# 17                                    56.9   8584926.0
# 18                                    57.6   8700471.0
# 19                                    57.8   8772865.0
# 20                                    57.7   8822267.0
# 21                                    58.2   8858775.0
# 22                                    62.3   8901064.0
# 28                                    49.7  10239085.0
# 29                                    50.4  10263414.0
# 30                                    51.5  10309725.0
# 31                                    52.9  10355844.0
# 32                                    53.5  10396421.0
# 33                                    55.6  10445852.0
# 34                                    56.1  10511382.0
# 35                                    56.8  10584534.0
# 36                                    52.7  10666866.0
# 37                                    53.9  10753080.0
# 38                                    54.8  10839905.0
# 39                                    54.4  11000638.0
# 40                                    53.4  11075889.0
# 41                                    52.8  11137974.0
# 42                                    53.8  11180840.0
# 43                                    53.5  11237274.0
# 44                                    53.5  11311117.0

# %%
joined.isna()
# Out:
#      country_name  region_id   year  municipal_waste_per_capita_kg  \
# 0           False      False  False                          False
# 1           False      False  False                          False
# 2           False      False  False                          False
# 3           False      False  False                          False
# 4           False      False  False                          False
# ..            ...        ...    ...                            ...
# 705         False      False  False                          False
# 706         False      False  False                          False
# 707         False      False  False                          False
# 708         False      False  False                          False
# 709         False      False  False                          False
#
#      recycling_rate_municipal_waste_percent  population
# 0                                     False       False
# 1                                     False       False
# 2                                     False       False
# 3                                     False       False
# 4                                     False       False
# ..                                      ...         ...
# 705                                   False       False
# 706                                   False       False
# 707                                   False       False
# 708                                   False       False
# 709                                   False       False
#
# [686 rows x 6 columns]

# %%
pd.options.display.max_rows = 100
joined
# Out:
#        country_name region_id  year  municipal_waste_per_capita_kg  \
# 0           Albania        AL  2020                            369
# 1           Albania        AL  2021                            311
# 2           Austria        AT  2000                            580
# 3           Austria        AT  2001                            576
# 4           Austria        AT  2002                            608
# ..              ...       ...   ...                            ...
# 705  United Kingdom        UK  2014                            482
# 706  United Kingdom        UK  2015                            483
# 707  United Kingdom        UK  2016                            483
# 708  United Kingdom        UK  2017                            468
# 709  United Kingdom        UK  2018                            463
#
#      recycling_rate_municipal_waste_percent  population
# 0                                      18.1   2845955.0
# 1                                      18.7   2829741.0
# 2                                      63.4   8002186.0
# 3                                      64.3   8020946.0
# 4                                      62.5   8063640.0
# ..                                      ...         ...
# 705                                    43.4  64351203.0
# 706                                    43.3  64853393.0
# 707                                    44.0  65379044.0
# 708                                    43.8  65844142.0
# 709                                    44.1  66273576.0
#
# [686 rows x 6 columns]

# %%
joined["row_num"]=np.arange(1, len(joined)+1)
joined
# Out:
#        country_name region_id  year  municipal_waste_per_capita_kg  \
# 0           Albania        AL  2020                            369
# 1           Albania        AL  2021                            311
# 2           Austria        AT  2000                            580
# 3           Austria        AT  2001                            576
# 4           Austria        AT  2002                            608
# ..              ...       ...   ...                            ...
# 705  United Kingdom        UK  2014                            482
# 706  United Kingdom        UK  2015                            483
# 707  United Kingdom        UK  2016                            483
# 708  United Kingdom        UK  2017                            468
# 709  United Kingdom        UK  2018                            463
#
#      recycling_rate_municipal_waste_percent  population  row_num
# 0                                      18.1   2845955.0        1
# 1                                      18.7   2829741.0        2
# 2                                      63.4   8002186.0        3
# 3                                      64.3   8020946.0        4
# 4                                      62.5   8063640.0        5
# ..                                      ...         ...      ...
# 705                                    43.4  64351203.0      682
# 706                                    43.3  64853393.0      683
# 707                                    44.0  65379044.0      684
# 708                                    43.8  65844142.0      685
# 709                                    44.1  66273576.0      686
#
# [686 rows x 7 columns]

# %%
#sorting by ["year"]
joined.sort_values(by="year", ascending = True, inplace=True)
joined.head()
# Out:
#     country_name region_id  year  municipal_waste_per_capita_kg  \
# 347      Ireland        IE  2000                            599
# 28       Belgium        BE  2000                            471
# 325      Hungary        HU  2000                            446
# 288       France        FR  2000                            514
# 266      Finland        FI  2000                            502
#
#      recycling_rate_municipal_waste_percent  population  row_num
# 347                                    11.9   3777565.0      343
# 28                                     49.7  10239085.0       24
# 325                                     1.6  10221644.0      321
# 288                                    24.5  60545022.0      284
# 266                                    33.6   5171302.0      262

# %%
# %matplotlib inline
import seaborn as sns  #for plotting
sns.set_style("darkgrid")
import matplotlib.pyplot as plt # for showing plots
from scipy import stats

# %%
from scipy.stats import pearsonr
joined_plot = joined[["municipal_waste_per_capita_kg","recycling_rate_municipal_waste_percent"]].dropna()
#determine the annotation's position
r = "r = " + str(round(pearsonr(joined_plot["municipal_waste_per_capita_kg"], joined_plot["recycling_rate_municipal_waste_percent"])[0], 2))
sns.kdeplot(data=joined, x= "municipal_waste_per_capita_kg", y="recycling_rate_municipal_waste_percent",  fill = True).annotate(r, xy=(50, 50), xycoords="data");

# %%
#check the correlation btw. "waste" and "recycle" (0.45 is medium, ok)
joined["municipal_waste_per_capita_kg"].corr(joined["recycling_rate_municipal_waste_percent"])
# Out:
# 0.43324813034586757

# %%
#check the correlation btw. "waste" and "population" (1,33)
joined["municipal_waste_per_capita_kg"].corr(joined["population"])
# Out:
# 1.3293586024134287e-05

# %%
#check the correlation btw. "recycle" and "population" (0,14 low)
joined["recycling_rate_municipal_waste_percent"].corr(joined["population"])
# Out:
# 0.14422822677446187

# %%
#plot Dataset 1
sns.lineplot(x="year", y="municipal_waste_per_capita_kg", data = joined)
plt.title('Municipal waste per capita (kg) in Europe')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot Dataset 2
sns.lineplot(x="year", y="recycling_rate_municipal_waste_percent", data = joined)
plt.title('Municipal recycling rate (%) in Europe')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot Dataset 3
sns.lineplot(x="year", y="population", data = joined)
plt.title('Population in Europe')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
! pip install jupyter-dash
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/dist-packages (from jupyter-dash) (1.5.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from jupyter-dash) (7.9.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from jupyter-dash) (5.3.4)
# Collecting dash
#   Downloading dash-2.9.1-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 64.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from jupyter-dash) (2.27.1)
# Requirement already satisfied: flask in /usr/local/lib/python3.9/dist-packages (from jupyter-dash) (2.2.3)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from dash->jupyter-dash) (5.13.1)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from flask->jupyter-dash) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from flask->jupyter-dash) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from flask->jupyter-dash) (6.0.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from flask->jupyter-dash) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from flask->jupyter-dash) (2.1.2)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter-dash) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter-dash) (5.7.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->jupyter-dash) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->jupyter-dash) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->jupyter-dash) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython->jupyter-dash) (63.4.3)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->jupyter-dash) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->jupyter-dash) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->jupyter-dash) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->jupyter-dash) (2.0.12)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from retrying->jupyter-dash) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->flask->jupyter-dash) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.2.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.6)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (23.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash) (3.1.1)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, retrying, jedi, ansi2html, dash, jupyter-dash
# Successfully installed ansi2html-1.8.0 dash-2.9.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 jedi-0.18.2 jupyter-dash-0.4.2 retrying-1.3.4

# %%
from jupyter_dash import JupyterDash
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Output, Input
import plotly.graph_objects as go
import plotly.express as px
# Out:
# <ipython-input-32-5a9b5e11e5c1>:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# <ipython-input-32-5a9b5e11e5c1>:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc

# %%
#a bar chart with a year-dropdown for Dataset 1
app = JupyterDash(__name__)


app.layout = html.Div([
    html.Header('Select the year:', style={"textAlign":"left"}),
    dcc.Dropdown(id='year_dropdown',
                 options= joined["year"].unique(),
                 value = 2000),
    dcc.Graph(id='waste_chart'),
])
   

@app.callback(Output("waste_chart", "figure"),
              Input("year_dropdown", "value"))
def sync_input(year_selection):
  #fix the height size to see all countries' names
  year_joined = joined[joined['year'] == 2000].sort_values('municipal_waste_per_capita_kg'
          , ascending=True)
  len_countries = len(year_joined["row_num"].unique())
  
  fig = px.bar(joined.loc[joined["year"]==year_selection].sort_values("municipal_waste_per_capita_kg", ascending=False),
               x="municipal_waste_per_capita_kg",
               y="country_name", color = "country_name", color_discrete_map = {'Ireland': 'rgb(70,130,180)', "Belgium": 'rgb(100,149,237)', 'Hungary':"rgb(0,191,255)", 'France':"rgb(30,144,255)", 'Finland': "rgb(135,206,235)",
       'European Union - 27 countries (from 2020)': "rgb(255,0,0)", 'Slovakia': "rgb(0,0,128)", 'Spain':"rgb(0,0,255)",
       'Greece':"rgb(138,43,226)", 'Estonia':"rgb(75,0,130)", 'Denmark' :"rgb(106,90,205)", 'Germany':"rgb(255,255,0)", 'Bulgaria':"rgb(186,85,211)", 'Czechia':"rgb(128,0,128)",
       'United Kingdom':"rgb(255,0,255)", 'Cyprus':"rgb(199,21,133)", 'Slovenia':"rgb(255,182,193)", 'Iceland':"rgb(176,196,222)", 'Switzerland':"rgb(220,20,60)",
       'Netherlands':"rgb(188,143,143)", "Norway":"rgb(64,224,208)", 'Malta':"rgb(139,69,19)", 'Sweden': "rgb(255,99,71)", 'Italy':"rgb(0,255,0)", 'Portugal':"rgb(222,184,135)",
       'Poland':"rgb(0,255,255)", 'Luxembourg':"rgb(60,179,113)", 'Austria':"rgb(173,255,47)", 'Latvia':"rgb(240,230,140)", 'Romania':"rgb(255,165,0)",
       'Lithuania':"rgb(128,0,0)", 'Croatia':"rgb(165,42,42)", 'Serbia':"rgb(255,215,0)", 'Türkiye': "rgb(128,128,0)", 'Montenegro':"rgb(0,0,0)",
       'Albania':"rgb(244,164,96)"},
               height = 20 + (25*len_countries),
               title = f'Europe & Municipal waste generation per capita (kg) - Year {year_selection}')
  fig.update_layout(yaxis_categoryorder='total ascending')
  
  return fig

app.run_server(mode="inline")
# Out:
# Dash is running on http://127.0.0.1:8050/
# INFO:dash.dash:Dash is running on http://127.0.0.1:8050/

# %%
#a bar chart with a year-dropdown for Dataset 1
app = JupyterDash(__name__)


app.layout = html.Div([
    html.Header('Select the year:', style={"textAlign":"left"}),
    dcc.Dropdown(id='year_dropdown',
                 options= joined["year"].unique(),
                 value = 2000),
    dcc.Graph(id='recycle_chart'),
])
   

@app.callback(Output("recycle_chart", "figure"),
              Input("year_dropdown", "value"))
def sync_input(year_selection):
  #fix the height size to see all countries' names
  year_joined = joined[joined['year'] == 2000].sort_values('recycling_rate_municipal_waste_percent'
          , ascending=True)
  len_countries = len(year_joined["row_num"].unique())
  
  fig1 = px.bar(joined.loc[joined["year"]==year_selection].sort_values("recycling_rate_municipal_waste_percent", ascending=False),
               x="recycling_rate_municipal_waste_percent",
               y="country_name", color = "country_name", color_discrete_map = {'Ireland': 'rgb(70,130,180)', "Belgium": 'rgb(100,149,237)', 'Hungary':"rgb(0,191,255)", 'France':"rgb(30,144,255)", 'Finland': "rgb(135,206,235)",
       'European Union - 27 countries (from 2020)': "rgb(255,0,0)", 'Slovakia': "rgb(0,0,128)", 'Spain':"rgb(0,0,255)",
       'Greece':"rgb(138,43,226)", 'Estonia':"rgb(75,0,130)", 'Denmark' :"rgb(106,90,205)", 'Germany':"rgb(255,255,0)", 'Bulgaria':"rgb(186,85,211)", 'Czechia':"rgb(128,0,128)",
       'United Kingdom':"rgb(255,0,255)", 'Cyprus':"rgb(199,21,133)", 'Slovenia':"rgb(255,182,193)", 'Iceland':"rgb(176,196,222)", 'Switzerland':"rgb(220,20,60)",
       'Netherlands':"rgb(188,143,143)", "Norway":"rgb(64,224,208)", 'Malta':"rgb(139,69,19)", 'Sweden': "rgb(255,99,71)", 'Italy':"rgb(0,255,0)", 'Portugal':"rgb(222,184,135)",
       'Poland':"rgb(0,255,255)", 'Luxembourg':"rgb(60,179,113)", 'Austria':"rgb(173,255,47)", 'Latvia':"rgb(240,230,140)", 'Romania':"rgb(255,165,0)",
       'Lithuania':"rgb(128,0,0)", 'Croatia':"rgb(165,42,42)", 'Serbia':"rgb(255,215,0)", 'Türkiye': "rgb(128,128,0)", 'Montenegro':"rgb(0,0,0)",
       'Albania':"rgb(244,164,96)"},
               height = 20 + (25*len_countries),
               title = f'Europe & Municipal recycling rate (%)- Year {year_selection}')
  fig1.update_layout(yaxis_categoryorder='total ascending')
  
  return fig1

app.run_server(mode="inline")
# Out:
# Dash is running on http://127.0.0.1:8050/
# INFO:dash.dash:Dash is running on http://127.0.0.1:8050/

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    dcc.Graph(id='graph-with-slider'),
    dcc.Slider(
        joined['year'].min(),
        joined['year'].max(),
        step=None,
        value=joined['year'].min(),
        marks={str(year): str(year) for year in joined['year'].unique()},
        id='year-slider'
    )
])

@app.callback(
    Output('graph-with-slider', 'figure'),
    Input('year-slider', 'value'))
def update_figure(selected_year):
 #fix the height size to see all countries' names
  year_joined = joined[joined['year'] == 2000].sort_values('recycling_rate_municipal_waste_percent'
          , ascending=True)
  len_countries = len(year_joined["row_num"].unique())

  filtered_joined = joined[joined["year"]== selected_year]

  fig3 = px.scatter(filtered_joined, x="recycling_rate_municipal_waste_percent",
                      y="municipal_waste_per_capita_kg", size="population",
                      hover_name="country_name", color = "country_name", color_discrete_map = {'Ireland': 'rgb(70,130,180)', "Belgium": 'rgb(100,149,237)', 'Hungary':"rgb(0,191,255)", 'France':"rgb(30,144,255)", 'Finland': "rgb(135,206,235)",
       'European Union - 27 countries (from 2020)': "rgb(255,0,0)", 'Slovakia': "rgb(0,0,128)", 'Spain':"rgb(0,0,255)",
       'Greece':"rgb(138,43,226)", 'Estonia':"rgb(75,0,130)", 'Denmark' :"rgb(106,90,205)", 'Germany':"rgb(255,255,0)", 'Bulgaria':"rgb(186,85,211)", 'Czechia':"rgb(128,0,128)",
       'United Kingdom':"rgb(255,0,255)", 'Cyprus':"rgb(199,21,133)", 'Slovenia':"rgb(255,182,193)", 'Iceland':"rgb(176,196,222)", 'Switzerland':"rgb(220,20,60)",
       'Netherlands':"rgb(188,143,143)", "Norway":"rgb(64,224,208)", 'Malta':"rgb(139,69,19)", 'Sweden': "rgb(255,99,71)", 'Italy':"rgb(0,255,0)", 'Portugal':"rgb(222,184,135)",
       'Poland':"rgb(0,255,255)", 'Luxembourg':"rgb(60,179,113)", 'Austria':"rgb(173,255,47)", 'Latvia':"rgb(240,230,140)", 'Romania':"rgb(255,165,0)",
       'Lithuania':"rgb(128,0,0)", 'Croatia':"rgb(165,42,42)", 'Serbia':"rgb(255,215,0)", 'Türkiye': "rgb(128,128,0)", 'Montenegro':"rgb(0,0,0)",
       'Albania':"rgb(244,164,96)"},
                      log_x=True, size_max=60, height = 20 + (25*len_countries),
                       title = f'Waste generation and recycling in Europe btw. 2000-2021')

  fig3.update_layout(transition_duration=500)

  return fig3

app.run_server(mode="inline")
# Out:
# Dash is running on http://127.0.0.1:8050/
# INFO:dash.dash:Dash is running on http://127.0.0.1:8050/

# %%
import urllib.request
url = "https://drive.google.com/uc?id=FILE_ID"
output_file = "path/to/output/file"
urllib.request.urlretrieve(url, output_file)
